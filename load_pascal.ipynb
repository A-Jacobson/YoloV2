# %% [markdown]
# ## YoloV2 for fast object detection

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
from torchvision import transforms
from datasets import PascalVOC, scale_bb

# %%
path =  '/home/austin/data/VOC/VOC2007/'

# %%
show_img = transforms.ToPILImage()
trans = transforms.Compose([transforms.Scale((224, 224)),
                                 transforms.ToTensor()])

# %%
voc = PascalVOC(root=path+'JPEGImages', annFile=path+"pascal_train2007.json", transform=trans)
# voc = PascalVOC(root=path+'JPEGImages', annFile=path+"pascal_train2007.json")
# Out:
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!

# %%
img = np.array(show_img(voc[0][0]))
# img = voc[0][0]

# %%
def create_rect(bb, color='Blue'):
    return plt.Rectangle((bb[0], bb[1]), bb[2], bb[3], fill=False, lw=3, color=color)

# %%
bb = voc[0][1]
target = scale_bb(voc[0][1], 224, 224)

# %%
bb = target[0]['bbox']

# %%
plt.imshow(img);
plt.gca().add_patch(create_rect(bb));

# %%
classes = ["aeroplane", "bicycle", "bird", "boat", "bottle", "bus", "car", "cat", "chair", "cow", "diningtable", "dog", "horse", "motorbike", "person", "pottedplant", "sheep", "sofa", "train", "tvmonitor"]

# %%
bb = voc[0][1][0]['bbox']

# %%
conv_x = (224. / 500)
conv_y = (224. / 333)
155 * conv_x
# Out:
# 69.44

# %%
bb = [52, 65, 88, 117]

# %%
8.0/160
# Out:
# 0.05

# %%
voc[1][1]
# Out:
# [{'area': 13110,
#   'bbox': [184, 61, 95, 138],
#   'category_id': 15,
#   'h': 364,
#   'id': 2,
#   'ignore': 0,
#   'image_id': 17,
#   'iscrowd': 0,
#   'segmentation': [[184, 61, 184, 199, 279, 199, 279, 61]],
#   'w': 480},
#  {'area': 81326,
#   'bbox': [89, 77, 314, 259],
#   'category_id': 13,
#   'id': 3,
#   'ignore': 0,
#   'image_id': 17,
#   'iscrowd': 0,
#   'segmentation': [[89, 77, 89, 336, 403, 336, 403, 77]]}]

# %%
classes[6]
# Out:
# 'car'
